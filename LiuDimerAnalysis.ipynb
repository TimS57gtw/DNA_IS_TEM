# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde, linregress
from scipy.optimize import curve_fit

# %%
# %matplotlib inline

# %% [markdown]
# ## Definde Functions

# %%
def linear_funct(x, intercept, slope):
    return intercept + x * slope

def linear_fit(x, y, dy=None):
    '''
    :return: intercept, gradient, d_inter, d_gradient
    '''
    with open('outf3.csv', 'w') as f:
        for a, b, c in zip(x, y, dy):
            f.write(f"{a};{b};{c}")
    a_fit,cov=curve_fit(linear_funct ,x ,y ,sigma=dy, absolute_sigma=True)
    return a_fit[0], a_fit[1], np.sqrt(cov[0][0]), np.sqrt(cov[1][1])

def density_plot(x, y, xlbl=None, ylbl=None):
    xy = np.vstack([x,y])
    z = gaussian_kde(xy)(xy)

    fig, ax = plt.subplots()
    ax.scatter(x, y, c=z, s=100)
    ax.set_xlabel(xlbl)
    ax.set_ylabel(ylbl)

def density_plot_spacing(x, y, xpts, xspans=None, xlbl=None, ylbl=None):

    pts_x = []
    pts_y = []
    unc_y = []
    for i, xp in enumerate(xpts):
        if i == 0:
            xlim_min = -np.inf
            xlim_max = (xpts[0] + xpts[1])/2
        elif i == len(xpts)-1:
            xlim_min = (xpts[i-1] + xpts[i])/2
            xlim_max = np.inf
        else:
            xlim_min = (xpts[i-1] + xpts[i])/2
            xlim_max = (xpts[i+1] + xpts[i])/2

        locvals = []
        for xval, yval in zip(x, y):
            if xlim_min < xval < xlim_max:
                locvals.append(yval)

        if len(locvals) > 0:
            pts_x.append(xp)
            pts_y.append(np.median(locvals))
            unc_y.append(np.sqrt(np.pi * (2 * len(locvals) + 1) / (4 * len(locvals))) * np.std(locvals) / np.sqrt(len(locvals)))


    xy = np.vstack([x,y])
    z = gaussian_kde(xy)(xy)

    fig, ax = plt.subplots()
    ax.scatter(x, y, c=z, s=100)
    ax.set_xlabel(xlbl)
    ax.set_ylabel(ylbl)

    ax.plot(pts_x, pts_y, c='red', label='median')
    ax.scatter(pts_x, pts_y, c='red', marker='x', s=50)
    ax.errorbar(pts_x, pts_y, yerr=unc_y, c='red')

    plt.legend()

def histo_evolution(x, y, xpts, xspans=None, xlbl=None, ylbl=None, bins=200):

    fig, ax = plt.subplots()
    keypts_x = []
    keypts_y = []
    kpy_sig = []

    mind = np.amin([abs(xpts[i] - xpts[i+1]) for i in range(len(xpts) - 1)])

    for i, xp in enumerate(xpts):
        if xspans is None:
            if i == 0:
                xlim_min = -np.inf
                xlim_max = (xpts[0] + xpts[1])/2
            elif i == len(xpts)-1:
                xlim_min = (xpts[i-1] + xpts[i])/2
                xlim_max = np.inf
            else:
                xlim_min = (xpts[i-1] + xpts[i])/2
                xlim_max = (xpts[i+1] + xpts[i])/2
        else:
            xlim_min = xp - xspans
            xlim_max = xp + xspans

        locvals = []
        for xval, yval in zip(x, y):
            if xlim_min < xval < xlim_max:
                locvals.append(yval)

        # print(locvals)
        if len(locvals) > 0:
            loc_hist = np.histogram(locvals, bins=bins)
            # print(loc_hist)
            histo_y = np.array(loc_hist[0], dtype=float)
            histo_x = np.array([(loc_hist[1][i] + loc_hist[1][i+1])/2 for i in range(len(loc_hist[1])-1)])
            histo_y/=np.amax(histo_y)
            histo_y *= mind
            histo_y += xp
            midpoint = np.median(locvals)
            keypts_x.append(midpoint)
            keypts_y.append(xp)
            n = len(locvals)
            kpy_sig.append(np.std(locvals) * np.sqrt(np.pi * (2*n+1) / (4*n)) / np.sqrt(n))
            # kpy_sig.append(np.std(locvals))
            ax.axhline(y=xp, c='gray', ls='--', alpha=0.8, lw=1)
            ax.plot(histo_x, histo_y, label=str(xp))
            ax.scatter([midpoint], [xp], marker='x', c='black', s=50)
            ax.errorbar([midpoint], [xp], xerr=kpy_sig[-1], marker='x', c='black')

    ax.set_xlabel(ylbl)
    ax.set_ylabel(xlbl)
    ax.plot(keypts_x, keypts_y, c='black', ls='--', lw=2)

    plt.legend(title=xlbl)
    with open('out2.csv', 'w') as f:
        for x, y, s in zip(keypts_x, keypts_y, kpy_sig):
            f.write(f'{y};{x};{s}\n')
    return keypts_y, keypts_x, kpy_sig

def histo_and_fit(x, y, xpts, xspans=None, xlbl=None, ylbl=None, bins=200, show_span=True):
    med_x, med_y, sig_y = histo_evolution(x, y, xpts, xspans, xlbl, ylbl, bins)
    plt.show()
    plt.scatter(med_x, med_y)
    plt.errorbar(med_x, med_y, yerr=sig_y)
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)

    med_x = np.array(med_x)
    med_y = np.array(med_y)
    sig_y = np.array(sig_y)

    # print(med_x.shape, med_x)
    # print(med_y.shape, med_y)
    # print(sig_y.shape, sig_y)
    res = linear_fit(med_x, med_y, sig_y)

    intercept = res[0]
    slope = res[1]
    d_intercept = res[2]
    d_slope = res[3]


    xs = np.linspace(min(med_x), max(med_x), 20)
    ys = [intercept + slope * x for x in xs]
    ys_max = [intercept + d_intercept + max( (slope + d_slope) * x, (slope - d_slope) * x) for x in xs]
    ys_min = [intercept - d_intercept + min( (slope + d_slope) * x, (slope - d_slope) * x) for x in xs]

    plt.plot(xs, ys)
    plt.plot(xs, ys_max, lw=1, c='gray', ls='--')
    plt.plot(xs, ys_min, lw=1, c='gray', ls='--')

    plt.title(f"({slope:.3f} $\pm$ {d_slope:.3f})x + ({intercept:.3f} $\pm$ {d_intercept:.3f})")

# %% [markdown]
# # Read Data

# %%
file = r"F:\Data\LiuDimer\Sizes\res.csv"
df = pd.read_csv(file, delimiter=';')

# %% [markdown]
# ## Filter Low-Confidence Detections

# %%
print("Total Detections",len(df))
# Out:
# Total Detections 11075

# %%
conf_th = 0.8
df = df[(df['conf'] > conf_th)]
print("Remaining Detections", len(df))
# Out:
# Remaining Detections 5518

# %%
df = df[(df['p1'] == 100)]

# %%
len(df)
# Out:
# 2325

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'total_id', 'img_id', 'crop_id', 'img_fn', 'crop_fn',
#        'p1', 'p2', 'p1_folder', 'p2_folder', 'short_axis', 'long_axis',
#        'p_xdir', 'p_ydir', 'cat', 'conf', 'w_px', 'h_px', 'grid_dist_x_nm',
#        'grid_dist_y_nm', 'grid_period_x_nm', 'grid_period_y_nm',
#        'on_grid_percentage', 'on_grid', 'mid_x_nm', 'mid_y_nm',
#        'centroid_x_nm', 'centroid_y_nm', 'NN1_nm', 'NN2_nm', 'NN3_nm',
#        'NN4_nm', 'NN5_nm', 'area', 'area_nm', 'span_x_nm', 'span_y_nm',
#        'span_long_axis_nm', 'span_short_axis_nm', 'long_axis_angle',
#        'rect_angle', 'rect_width_nm', 'rect_height_nm', 'rect_area_nm',
#        'rect_iou'],
#       dtype='object')

# %% [markdown]
# # Correlation of Parameters

# %%
corr = df.corr(numeric_only=True)
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format('{:.2f}')
# Out:
# <style type="text/css">
# #T_c2d7e_row0_col0, #T_c2d7e_row0_col1, #T_c2d7e_row0_col2, #T_c2d7e_row1_col0, #T_c2d7e_row1_col1, #T_c2d7e_row1_col2, #T_c2d7e_row2_col0, #T_c2d7e_row2_col1, #T_c2d7e_row2_col2, #T_c2d7e_row3_col3, #T_c2d7e_row5_col5, #T_c2d7e_row5_col7, #T_c2d7e_row5_col11, #T_c2d7e_row7_col5, #T_c2d7e_row7_col7, #T_c2d7e_row7_col11, #T_c2d7e_row11_col5, #T_c2d7e_row11_col7, #T_c2d7e_row11_col11, #T_c2d7e_row13_col13, #T_c2d7e_row16_col16, #T_c2d7e_row17_col17, #T_c2d7e_row18_col18, #T_c2d7e_row19_col19, #T_c2d7e_row20_col20, #T_c2d7e_row21_col21, #T_c2d7e_row22_col22, #T_c2d7e_row22_col24, #T_c2d7e_row23_col23, #T_c2d7e_row23_col25, #T_c2d7e_row24_col22, #T_c2d7e_row24_col24, #T_c2d7e_row25_col23, #T_c2d7e_row25_col25, #T_c2d7e_row26_col26, #T_c2d7e_row27_col27, #T_c2d7e_row28_col28, #T_c2d7e_row29_col29, #T_c2d7e_row30_col30, #T_c2d7e_row31_col31, #T_c2d7e_row31_col32, #T_c2d7e_row32_col31, #T_c2d7e_row32_col32, #T_c2d7e_row33_col33, #T_c2d7e_row34_col34, #T_c2d7e_row35_col35, #T_c2d7e_row36_col36, #T_c2d7e_row37_col37, #T_c2d7e_row38_col38, #T_c2d7e_row39_col39, #T_c2d7e_row40_col40, #T_c2d7e_row41_col41, #T_c2d7e_row42_col42 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c2d7e_row0_col3, #T_c2d7e_row1_col3, #T_c2d7e_row3_col0, #T_c2d7e_row3_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_c2d7e_row0_col4, #T_c2d7e_row0_col6, #T_c2d7e_row0_col8, #T_c2d7e_row0_col9, #T_c2d7e_row0_col10, #T_c2d7e_row0_col12, #T_c2d7e_row0_col14, #T_c2d7e_row0_col15, #T_c2d7e_row1_col4, #T_c2d7e_row1_col6, #T_c2d7e_row1_col8, #T_c2d7e_row1_col9, #T_c2d7e_row1_col10, #T_c2d7e_row1_col12, #T_c2d7e_row1_col14, #T_c2d7e_row1_col15, #T_c2d7e_row2_col4, #T_c2d7e_row2_col6, #T_c2d7e_row2_col8, #T_c2d7e_row2_col9, #T_c2d7e_row2_col10, #T_c2d7e_row2_col12, #T_c2d7e_row2_col14, #T_c2d7e_row2_col15, #T_c2d7e_row3_col4, #T_c2d7e_row3_col6, #T_c2d7e_row3_col8, #T_c2d7e_row3_col9, #T_c2d7e_row3_col10, #T_c2d7e_row3_col12, #T_c2d7e_row3_col14, #T_c2d7e_row3_col15, #T_c2d7e_row4_col0, #T_c2d7e_row4_col1, #T_c2d7e_row4_col2, #T_c2d7e_row4_col3, #T_c2d7e_row4_col4, #T_c2d7e_row4_col5, #T_c2d7e_row4_col6, #T_c2d7e_row4_col7, #T_c2d7e_row4_col8, #T_c2d7e_row4_col9, #T_c2d7e_row4_col10, #T_c2d7e_row4_col11, #T_c2d7e_row4_col12, #T_c2d7e_row4_col13, #T_c2d7e_row4_col14, #T_c2d7e_row4_col15, #T_c2d7e_row4_col16, #T_c2d7e_row4_col17, #T_c2d7e_row4_col18, #T_c2d7e_row4_col19, #T_c2d7e_row4_col20, #T_c2d7e_row4_col21, #T_c2d7e_row4_col22, #T_c2d7e_row4_col23, #T_c2d7e_row4_col24, #T_c2d7e_row4_col25, #T_c2d7e_row4_col26, #T_c2d7e_row4_col27, #T_c2d7e_row4_col28, #T_c2d7e_row4_col29, #T_c2d7e_row4_col30, #T_c2d7e_row4_col31, #T_c2d7e_row4_col32, #T_c2d7e_row4_col33, #T_c2d7e_row4_col34, #T_c2d7e_row4_col35, #T_c2d7e_row4_col36, #T_c2d7e_row4_col37, #T_c2d7e_row4_col38, #T_c2d7e_row4_col39, #T_c2d7e_row4_col40, #T_c2d7e_row4_col41, #T_c2d7e_row4_col42, #T_c2d7e_row5_col4, #T_c2d7e_row5_col6, #T_c2d7e_row5_col8, #T_c2d7e_row5_col9, #T_c2d7e_row5_col10, #T_c2d7e_row5_col12, #T_c2d7e_row5_col14, #T_c2d7e_row5_col15, #T_c2d7e_row6_col0, #T_c2d7e_row6_col1, #T_c2d7e_row6_col2, #T_c2d7e_row6_col3, #T_c2d7e_row6_col4, #T_c2d7e_row6_col5, #T_c2d7e_row6_col6, #T_c2d7e_row6_col7, #T_c2d7e_row6_col8, #T_c2d7e_row6_col9, #T_c2d7e_row6_col10, #T_c2d7e_row6_col11, #T_c2d7e_row6_col12, #T_c2d7e_row6_col13, #T_c2d7e_row6_col14, #T_c2d7e_row6_col15, #T_c2d7e_row6_col16, #T_c2d7e_row6_col17, #T_c2d7e_row6_col18, #T_c2d7e_row6_col19, #T_c2d7e_row6_col20, #T_c2d7e_row6_col21, #T_c2d7e_row6_col22, #T_c2d7e_row6_col23, #T_c2d7e_row6_col24, #T_c2d7e_row6_col25, #T_c2d7e_row6_col26, #T_c2d7e_row6_col27, #T_c2d7e_row6_col28, #T_c2d7e_row6_col29, #T_c2d7e_row6_col30, #T_c2d7e_row6_col31, #T_c2d7e_row6_col32, #T_c2d7e_row6_col33, #T_c2d7e_row6_col34, #T_c2d7e_row6_col35, #T_c2d7e_row6_col36, #T_c2d7e_row6_col37, #T_c2d7e_row6_col38, #T_c2d7e_row6_col39, #T_c2d7e_row6_col40, #T_c2d7e_row6_col41, #T_c2d7e_row6_col42, #T_c2d7e_row7_col4, #T_c2d7e_row7_col6, #T_c2d7e_row7_col8, #T_c2d7e_row7_col9, #T_c2d7e_row7_col10, #T_c2d7e_row7_col12, #T_c2d7e_row7_col14, #T_c2d7e_row7_col15, #T_c2d7e_row8_col0, #T_c2d7e_row8_col1, #T_c2d7e_row8_col2, #T_c2d7e_row8_col3, #T_c2d7e_row8_col4, #T_c2d7e_row8_col5, #T_c2d7e_row8_col6, #T_c2d7e_row8_col7, #T_c2d7e_row8_col8, #T_c2d7e_row8_col9, #T_c2d7e_row8_col10, #T_c2d7e_row8_col11, #T_c2d7e_row8_col12, #T_c2d7e_row8_col13, #T_c2d7e_row8_col14, #T_c2d7e_row8_col15, #T_c2d7e_row8_col16, #T_c2d7e_row8_col17, #T_c2d7e_row8_col18, #T_c2d7e_row8_col19, #T_c2d7e_row8_col20, #T_c2d7e_row8_col21, #T_c2d7e_row8_col22, #T_c2d7e_row8_col23, #T_c2d7e_row8_col24, #T_c2d7e_row8_col25, #T_c2d7e_row8_col26, #T_c2d7e_row8_col27, #T_c2d7e_row8_col28, #T_c2d7e_row8_col29, #T_c2d7e_row8_col30, #T_c2d7e_row8_col31, #T_c2d7e_row8_col32, #T_c2d7e_row8_col33, #T_c2d7e_row8_col34, #T_c2d7e_row8_col35, #T_c2d7e_row8_col36, #T_c2d7e_row8_col37, #T_c2d7e_row8_col38, #T_c2d7e_row8_col39, #T_c2d7e_row8_col40, #T_c2d7e_row8_col41, #T_c2d7e_row8_col42, #T_c2d7e_row9_col0, #T_c2d7e_row9_col1, #T_c2d7e_row9_col2, #T_c2d7e_row9_col3, #T_c2d7e_row9_col4, #T_c2d7e_row9_col5, #T_c2d7e_row9_col6, #T_c2d7e_row9_col7, #T_c2d7e_row9_col8, #T_c2d7e_row9_col9, #T_c2d7e_row9_col10, #T_c2d7e_row9_col11, #T_c2d7e_row9_col12, #T_c2d7e_row9_col13, #T_c2d7e_row9_col14, #T_c2d7e_row9_col15, #T_c2d7e_ro ...

# %% [markdown]
# ## Size of molecules

# %%
df_short = pd.DataFrame()
df_short['p1'] = df['p1']
df_short['p2'] = df['p2']
df_short['span_x_nm'] = df['span_x_nm']
df_short['span_y_nm'] = df['span_y_nm']
df_short['rect_width_nm'] = df['rect_width_nm']
df_short['rect_height_nm'] = df['rect_height_nm']
corr = df_short.corr(numeric_only=True)
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format('{:.2f}')
# Out:
# <style type="text/css">
# #T_ac167_row0_col0, #T_ac167_row0_col1, #T_ac167_row0_col2, #T_ac167_row0_col3, #T_ac167_row0_col4, #T_ac167_row0_col5, #T_ac167_row1_col0, #T_ac167_row2_col0, #T_ac167_row3_col0, #T_ac167_row4_col0, #T_ac167_row5_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ac167_row1_col1, #T_ac167_row2_col2, #T_ac167_row3_col3, #T_ac167_row4_col4, #T_ac167_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ac167_row1_col2, #T_ac167_row1_col4, #T_ac167_row2_col1, #T_ac167_row4_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ac167_row1_col3, #T_ac167_row3_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_ac167_row1_col5, #T_ac167_row5_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ac167_row2_col3, #T_ac167_row3_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_ac167_row2_col4, #T_ac167_row4_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_ac167_row2_col5, #T_ac167_row5_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_ac167_row3_col4, #T_ac167_row4_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_ac167_row3_col5, #T_ac167_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ac167_row4_col5, #T_ac167_row5_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# </style>
# <table id="T_ac167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac167_level0_col0" class="col_heading level0 col0" >p1</th>
#       <th id="T_ac167_level0_col1" class="col_heading level0 col1" >p2</th>
#       <th id="T_ac167_level0_col2" class="col_heading level0 col2" >span_x_nm</th>
#       <th id="T_ac167_level0_col3" class="col_heading level0 col3" >span_y_nm</th>
#       <th id="T_ac167_level0_col4" class="col_heading level0 col4" >rect_width_nm</th>
#       <th id="T_ac167_level0_col5" class="col_heading level0 col5" >rect_height_nm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac167_level0_row0" class="row_heading level0 row0" >p1</th>
#       <td id="T_ac167_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_ac167_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_ac167_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_ac167_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_ac167_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_ac167_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ac167_level0_row1" class="row_heading level0 row1" >p2</th>
#       <td id="T_ac167_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_ac167_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ac167_row1_col2" class="data row1 col2" >-0.01</td>
#       <td id="T_ac167_row1_col3" class="data row1 col3" >0.67</td>
#       <td id="T_ac167_row1_col4" class="data row1 col4" >-0.01</td>
#       <td id="T_ac167_row1_col5" class="data row1 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_ac167_level0_row2" class="row_heading level0 row2" >span_x_nm</th>
#       <td id="T_ac167_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_ac167_row2_col1" class="data row2 col1" >-0.01</td>
#       <td id="T_ac167_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ac167_row2_col3" class="data row2 col3" >0.21</td>
#       <td id="T_ac167_row2_col4" class="data row2 col4" >0.82</td>
#       <td id="T_ac167_row2_col5" class="data row2 col5" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_ac167_level0_row3" class="row_heading level0 row3" >span_y_nm</th>
#       <td id="T_ac167_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_ac167_row3_col1" class="data row3 col1" >0.67</td>
#       <td id="T_ac167_row3_col2" class="data row3 col2" >0.21</td>
#       <td id="T_ac167_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_ac167_row3_col4" class="data row3 col4" >0.14</td>
#       <td id="T_ac167_row3_col5" class="data row3 col5" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_ac167_level0_row4" class="row_heading level0 row4" >rect_width_nm</th>
#       <td id="T_ac167_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_ac167_row4_col1" class="data row4 col1" >-0.01</td>
#       <td id="T_ac167_row4_col2" class="data row4 col2" >0.82</td>
#       <td id="T_ac167_row4_col3" class="data row4 col3" >0.14</td>
#       <td id="T_ac167_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_ac167_row4_col5" class="data row4 col5" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_ac167_level0_row5" class="row_heading level0 row5" >rect_height_nm</th>
#       <td id="T_ac167_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_ac167_row5_col1" class="data row5 col1" >0.01</td>
#       <td id="T_ac167_row5_col2" class="data row5 col2" >0.40</td>
#       <td id="T_ac167_row5_col3" class="data row5 col3" >0.09</td>
#       <td id="T_ac167_row5_col4" class="data row5 col4" >0.42</td>
#       <td id="T_ac167_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Orientation of Molecules

# %%
df_short = pd.DataFrame()
df_short['p1'] = df['p1']
df_short['p2'] = df['p2']
df_short['p_aspectRatio'] = [a / b for a, b in zip(df['p_xdir'], df['p_ydir'])]
df_short['rect_angle'] = df['rect_angle']
df_short['rect_aspect'] = [a / b for a, b in zip(df['rect_width_nm'], df['rect_height_nm'])]
df_short['span_aspect'] = [a / b for a, b in zip(df['span_x_nm'], df['span_y_nm'])]
corr = df_short.corr(numeric_only=True)
corr.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format('{:.2f}')
# Out:
# <style type="text/css">
# #T_45d08_row0_col0, #T_45d08_row1_col1, #T_45d08_row2_col2, #T_45d08_row3_col3, #T_45d08_row4_col4, #T_45d08_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_45d08_row0_col1, #T_45d08_row1_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_45d08_row0_col2, #T_45d08_row2_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_45d08_row0_col3, #T_45d08_row3_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_45d08_row0_col4, #T_45d08_row4_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_45d08_row0_col5, #T_45d08_row5_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_45d08_row1_col2, #T_45d08_row2_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_45d08_row1_col3, #T_45d08_row3_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_45d08_row1_col4, #T_45d08_row4_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_45d08_row1_col5, #T_45d08_row5_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_45d08_row2_col3, #T_45d08_row3_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_45d08_row2_col4, #T_45d08_row4_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_45d08_row2_col5, #T_45d08_row5_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_45d08_row3_col4, #T_45d08_row4_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_45d08_row3_col5, #T_45d08_row5_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_45d08_row4_col5, #T_45d08_row5_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# </style>
# <table id="T_45d08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45d08_level0_col0" class="col_heading level0 col0" >p_xdir</th>
#       <th id="T_45d08_level0_col1" class="col_heading level0 col1" >p_ydir</th>
#       <th id="T_45d08_level0_col2" class="col_heading level0 col2" >p_aspectRatio</th>
#       <th id="T_45d08_level0_col3" class="col_heading level0 col3" >rect_angle</th>
#       <th id="T_45d08_level0_col4" class="col_heading level0 col4" >rect_aspect</th>
#       <th id="T_45d08_level0_col5" class="col_heading level0 col5" >span_aspect</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45d08_level0_row0" class="row_heading level0 row0" >p_xdir</th>
#       <td id="T_45d08_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_45d08_row0_col1" class="data row0 col1" >-0.10</td>
#       <td id="T_45d08_row0_col2" class="data row0 col2" >0.54</td>
#       <td id="T_45d08_row0_col3" class="data row0 col3" >0.07</td>
#       <td id="T_45d08_row0_col4" class="data row0 col4" >-0.14</td>
#       <td id="T_45d08_row0_col5" class="data row0 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_45d08_level0_row1" class="row_heading level0 row1" >p_ydir</th>
#       <td id="T_45d08_row1_col0" class="data row1 col0" >-0.10</td>
#       <td id="T_45d08_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_45d08_row1_col2" class="data row1 col2" >-0.69</td>
#       <td id="T_45d08_row1_col3" class="data row1 col3" >-0.14</td>
#       <td id="T_45d08_row1_col4" class="data row1 col4" >-0.07</td>
#       <td id="T_45d08_row1_col5" class="data row1 col5" >-0.40</td>
#     </tr>
#     <tr>
#       <th id="T_45d08_level0_row2" class="row_heading level0 row2" >p_aspectRatio</th>
#       <td id="T_45d08_row2_col0" class="data row2 col0" >0.54</td>
#       <td id="T_45d08_row2_col1" class="data row2 col1" >-0.69</td>
#       <td id="T_45d08_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_45d08_row2_col3" class="data row2 col3" >0.15</td>
#       <td id="T_45d08_row2_col4" class="data row2 col4" >-0.05</td>
#       <td id="T_45d08_row2_col5" class="data row2 col5" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_45d08_level0_row3" class="row_heading level0 row3" >rect_angle</th>
#       <td id="T_45d08_row3_col0" class="data row3 col0" >0.07</td>
#       <td id="T_45d08_row3_col1" class="data row3 col1" >-0.14</td>
#       <td id="T_45d08_row3_col2" class="data row3 col2" >0.15</td>
#       <td id="T_45d08_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_45d08_row3_col4" class="data row3 col4" >-0.74</td>
#       <td id="T_45d08_row3_col5" class="data row3 col5" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_45d08_level0_row4" class="row_heading level0 row4" >rect_aspect</th>
#       <td id="T_45d08_row4_col0" class="data row4 col0" >-0.14</td>
#       <td id="T_45d08_row4_col1" class="data row4 col1" >-0.07</td>
#       <td id="T_45d08_row4_col2" class="data row4 col2" >-0.05</td>
#       <td id="T_45d08_row4_col3" class="data row4 col3" >-0.74</td>
#       <td id="T_45d08_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_45d08_row4_col5" class="data row4 col5" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_45d08_level0_row5" class="row_heading level0 row5" >span_aspect</th>
#       <td id="T_45d08_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_45d08_row5_col1" class="data row5 col1" >-0.40</td>
#       <td id="T_45d08_row5_col2" class="data row5 col2" >0.40</td>
#       <td id="T_45d08_row5_col3" class="data row5 col3" >0.25</td>
#       <td id="T_45d08_row5_col4" class="data row5 col4" >0.10</td>
#       <td id="T_45d08_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Patch Size vs. Molecule Size

# %% [markdown]
# ## Molecule Span

# %%
histo_and_fit(df['p_xdir'], df['span_x_nm'], xpts=[10 * x for x in range(20)], xlbl='p_xdir', ylbl='span_x_nm', bins=20)

# %%
histo_and_fit(df['p_xdir'], df['span_y_nm'], xpts=[10 * x for x in range(20)], xlbl='p_xdir', ylbl='span_y_nm', bins=20)

# %%
histo_and_fit(df['p_ydir'], df['span_x_nm'], xpts=[10 * x for x in range(20)], xlbl='p_ydir', ylbl='span_x_nm', bins=20)

# %%
histo_and_fit(df['p_ydir'], df['span_y_nm'], xpts=[10 * x for x in range(20)], xlbl='p_ydir', ylbl='span_y_nm', bins=20)

# %% [markdown]
# ## Rectangle Size

# %%
histo_and_fit(df['p2'], df['rect_width_nm'], xpts=[10 * x for x in range(20)], xlbl='p2', ylbl='rect_width_nm', bins=20)

# %%
np.unique(list(df['p1']))
# Out:
# array([100])

# %%
histo_and_fit(df['p2'], df['span_y_nm'], xpts=[10 * x for x in range(20)], xlbl='p2', ylbl='span_y_nm', bins=20)

# %%
histo_and_fit(df['p_xdir'], df['rect_height_nm'], xpts=[10 * x for x in range(20)], xlbl='p_xdir', ylbl='rect_height_nm', bins=20)

# %%
histo_and_fit(df['p_ydir'], df['rect_width_nm'], xpts=[10 * x for x in range(20)], xlbl='p_ydir', ylbl='rect_width_nm', bins=20)

# %%
histo_and_fit(df['p_ydir'], df['rect_height_nm'], xpts=[10 * x for x in range(20)], xlbl='p_ydir', ylbl='rect_height_nm', bins=20)

# %%
srt = [list(df['p2'])[i] for i in range(len(df['p2'])) if list(df['p1'])[i] == 100]

# %% [markdown]
# # Short axis

# %%
import copy

# %%
dfsrt = copy.deepcopy(df)

# %%
dfsrt = dfsrt[(dfsrt['short_axis'] == 1)]

# %%
len(dfsrt)
# Out:
# 2325

# %% [markdown]
# # Long Axis

# %%
file = r"F:\Data\LiuDimer\Sizes\res.csv"
dflong = pd.read_csv(file, delimiter=';')

# %%
len(dflong)
# Out:
# 11075

# %%
dflong = dflong[(dflong['long_axis'] == 1)]

# %%
len(dflong)
# Out:
# 6467

# %%
dflong = dflong[(dflong['conf'] > 0.8)]

# %%
len(dflong)
# Out:
# 2782

# %%
dflong = dflong[(dflong['p2'] == 20)]

# %%
len(dflong)
# Out:
# 2289

# %%
histo_and_fit(dflong['p1'], dflong['span_x_nm'], xpts=[10 * x for x in range(20)], xlbl='p1', ylbl='span_x_nm', bins=20)

# %%
histo_and_fit(dflong['p1'], dflong['span_y_nm'], xpts=[10 * x for x in range(20)], xlbl='p1', ylbl='span_y_nm', bins=20)

# %% [markdown]
# # Export Data

# %% [markdown]
# ## Short Axis

# %%
file = r"F:\Data\LiuDimer\Sizes\res.csv"
df = pd.read_csv(file, delimiter=';')
df = df[(df['conf'] > 0.8)]
len(df)
# Out:
# 5518

# %%
df = df[(df['p1'] == 100)]

# %%
len(df)
# Out:
# 2325

# %%
sum(list(df['short_axis']))
# Out:
# 2325

# %%
p2s = np.unique(df['p2'])
for p2 in p2s:
    outf = f'shortAxis_100x{p2}.csv'
    with open(outf, 'w') as f:
        f.write('span_x (nm) ;span_y (nm)\n')
        dfp = copy.deepcopy(df)
        dfp = dfp[dfp['p2'] == p2]
        for i in range(len(dfp)):
            f.write(f"{list(dfp['span_x_nm'])[i]};{list(dfp['span_y_nm'])[i]}\n")

# %% [markdown]
# ## Long Axis

# %%
file = r"F:\Data\LiuDimer\Sizes\res.csv"
df = pd.read_csv(file, delimiter=';')
df = df[(df['conf'] > 0.8)]
len(df)
# Out:
# 5518

# %%
df = df[(df['p2'] == 20)]

# %%
p1s = np.unique(df['p1'])
for p1 in p1s:
    outf = f'longAxis_{p1}x20.csv'
    with open(outf, 'w') as f:
        f.write('span_x (nm) ;span_y (nm)\n')
        dfp = copy.deepcopy(df)
        dfp = dfp[dfp['p1'] == p1]
        for i in range(len(dfp)):
            f.write(f"{list(dfp['span_x_nm'])[i]};{list(dfp['span_y_nm'])[i]}\n")
